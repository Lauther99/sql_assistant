# %%
import sys
sys.path.append("C:\\Users\\lauth\\OneDrive\\Desktop\\sql_assistant_v3")

# %%
# Modelos LLM
from src.components.models.embeddings.embeddings import HF_MultilingualE5_Embeddings, Openai_Embeddings
from src.components.models.llms.llms import HF_Llama38b_LLM, Openai_LLM


hf_llm = HF_Llama38b_LLM()
openai_llm = Openai_LLM()

# Modelos Embeddings
mle5_embeddings = HF_MultilingualE5_Embeddings()
openai_embeddings = Openai_Embeddings()

#Iniciando los modelos
openai_llm.init_model()
hf_llm.init_model()
mle5_embeddings.init_model()
openai_embeddings.init_model()

# %%
from src.db.chroma_db.handlers.handlers import (
    add_base_columns,
    melt_columns,
    process_searched_columns,
    process_searched_relations,
    query_by_vector_embedding,
)
from src.settings.settings import Settings
from experiments.experiments_settings.settings import Experiments_Settings
from src.components.models.models_interfaces import Base_Embeddings
from src.utils.utils import clean_sentence


def retrieve_sql_semantic_information_improved(
    keywords_arr: list[str],
    embeddings: Base_Embeddings,
    relations_search_properties: dict[str, any] = {"n": 5, "score_threshold": 0.7},
    columns_search_properties: dict[str, any] = {"n": 4, "score_threshold": 0.6},
):
    """ """
    vectors = []
    relations_collection = Experiments_Settings.Chroma.get_experiments_semantic_relations_collection()
    columns_collection = Experiments_Settings.Chroma.get_experiments_semantic_columns()
    
    tables = set()
    results_columns_collection = tuple()
    combined_dict = {}
    tables_related = [] # Arreglo de tablas con columnas necesarias para JOINS 
    table_relations_descriptions = set()
    
    # Parte 0: Vectorizando las palabras
    for kw_item in keywords_arr:
        v = embeddings.get_embeddings(clean_sentence(kw_item))
        vectors.append(v)
    
    # Parte 1: Buscamos las tablas
    for _, kw_vector in enumerate(vectors):
        # Buscamos en la db
        results_relations_collection = query_by_vector_embedding(
            collection=relations_collection,
            vector_embedding=kw_vector,
            n=relations_search_properties["n"],
            score_threshold=relations_search_properties["score_threshold"],
            metadata_filters={},
        )
        if not results_relations_collection:
            continue

        # Formateamos la data recuperada
        if len(results_relations_collection) > 0:
            x = process_searched_relations(items=results_relations_collection, tables_related={})
            tables_related.append(x["tables_related"]) 
            table_relations_descriptions.update(x["table_relations_descriptions"]) 
            
            tables = set(x["tables_related"].keys()).union(tables)
            
    # Parte 2: Busqueda semantica de columnas (porsiacaso una extra jeje)
    for _, kw_vector in enumerate(vectors):
        for table in tables:
            results_columns_collection += query_by_vector_embedding(
                collection=columns_collection,
                vector_embedding=kw_vector,
                n=columns_search_properties["n"],
                score_threshold=columns_search_properties["score_threshold"],
                metadata_filters={"meta_table": {"$eq": table}},
            )        
            if len(results_columns_collection) > 0:
                current_data = process_searched_columns(results_columns_collection, {}, 0)
                combined_dict.update(add_base_columns(tables, current_data))
            else:
                combined_dict.update(add_base_columns(tables, {}))
        
    # Parte 3: Merge de las columnas normales y las columnas para JOINS
    resultado_columnas = melt_columns(tables_related, combined_dict)
    
    return (
        tables,
        resultado_columnas,
        (
           table_relations_descriptions
            if table_relations_descriptions
            else []
        ),
    )

# %%
request_2 = ['equipment type classification', 'measurement data', 'measurement system', 'firmware', 'variable']

r_2 = retrieve_sql_semantic_information_improved(request_2, openai_embeddings)

# %%
r_2[0]
# Out:
# {'equ_equipo',
#  'fcs_computador_medidor',
#  'fcs_computadores',
#  'fcs_firmware',
#  'fcs_tipo_computador',
#  'flu_tipo_fluido',
#  'med_sistema_medicion',
#  'med_tag',
#  'med_tipo_medicion',
#  'pla_plataforma',
#  'teq_clasificacion',
#  'teq_tipo_equipo',
#  'var_tipo_variable',
#  'var_variable_datos'}

# %%
from src.utils.reader_utils import read_database_semantics, read_tables_data

create_table_template = """CREATE TABLE IF NOT EXISTS dbo_v2.{table_name}(\n{list_columns_plus_type_plus_descriptions});"""

def _add_ddl_in_prompt(semantic_info: dict[str, any]):
    ddls = list()
    ddl_text = ""
    
    for table in semantic_info:
        list_columns_plus_type_plus_descriptions = set()
        for item in semantic_info[table]:
            elementos = [item[4]] if isinstance(item[4], str) else list(item[4])
            if all(elemento in semantic_info for elemento in elementos):
                list_columns_plus_type_plus_descriptions.add(
                    (f"\t{item[0]} {item[1]} -- Description: {item[2]},\n", item[3])
                )
        # Crear una lista ordenada de las columnas basadas en la prioridad
        ordered_list = sorted(
            list_columns_plus_type_plus_descriptions, key=lambda x: x[1]
        )
        list_columns_plus_type_plus_descriptions = "".join(
            tupla[0] for tupla in ordered_list
        )
        t = create_table_template.format(
            table_name=table,
            list_columns_plus_type_plus_descriptions=list_columns_plus_type_plus_descriptions,
        )
        ddls.append(t)

    tables_context = "\n".join(ddls)
    ddl_text += f"\n{tables_context}\n\n"
    
    rel = read_database_semantics(
        "relations", ["table_1", "table_2", "join_description"]
    )
    for _, item in rel.iterrows():
        table_1_plus_table_2 = [item["table_1"], item["table_2"]]
        if all(elemento in semantic_info for elemento in table_1_plus_table_2):
            ddl_text += f"""{item["join_description"]}\n"""

    return ddl_text

# %%
a = _add_ddl_in_prompt(r_2[1])
print(a)
# Out:
# CREATE TABLE IF NOT EXISTS dbo_v2.pla_plataforma(
# 	Id INT -- Description: Unique Identifier for each platform,
# 	Nombre VARCHAR(MAX) -- Description: Platform name,
# 	Estado VARCHAR(10) -- Description: Platform status, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.flu_tipo_fluido(
# 	Id INT -- Description: Unique identifier for the fluid type,
# 	Nombre VARCHAR(100) -- Description: Name of the fluid type, must be in: (Gás Natural / Óleo Cru / Água / Condensado / Vapour / Água + MEG / MEG),
# 	Estado VARCHAR(100) -- Description: Fluid type status, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.med_tipo_medicion(
# 	Id INT -- Description: Unique identifier for each measure type,
# 	Nombre VARCHAR(150) -- Description: Name of the measurement type,
# 	Estado VARCHAR(10) -- Description: Status of the measurement type, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.med_sistema_medicion(
# 	Id INT -- Description: Unique identifier for the measurement system,
# 	Nombre VARCHAR(100) -- Description: Name of the measurement system,
# 	Tag VARCHAR(100) -- Description: Tag associated to the measurement system,
# 	Estado VARCHAR(100) -- Description: Status of the measurement system, active ('ACT') or inactive ('INA'),
# 	Uso VARCHAR(100) -- Description: Usage description of the measurement system could be: CONTINUA / WELL_TESTING,
# 	IdTipoFluido_fk INT -- Description: Foreign key linking fluid type with measurement systems,
# 	IdAplicabilidad_fk INT -- Description: Foreign key linking measurement system with their measure type,
# 	IdPlataforma_fk INT -- Description: Foreign key linking measurement systems with platforms,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.fcs_tipo_computador(
# 	Id INT -- Description: Unique identifier for each flow computer type,
# 	Nombre VARCHAR(50) -- Description: Name or designation of the flow computer type (e.g., OMNI, KHRONE, S600, FC302, FLOWBOSS, F407, F107, Thermofischer),
# 	Estado VARCHAR(10) -- Description: Status of the computer flow type, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.fcs_firmware(
# 	Id INT -- Description: Unique identifier for each flow computer firmware,
# 	Firmware VARCHAR(100) -- Description: Name or version of the firmware,
# 	Estado VARCHAR(10) -- Description: Status of the firmware, active ('ACT') or inactive ('INA'),
# 	IdTipo_Computador INT -- Description: Foreign key linking firmwares with flow computer types,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.fcs_computadores(
# 	Id INT -- Description: Unique identifier for each flow computer,
# 	IP VARCHAR(100) -- Description: Flow computer IP address of the flow computer,
# 	Puerto INT -- Description: Flow computer primary port used for communications,
# 	Tag VARCHAR(100) -- Description: Flow computer name,
# 	Estado VARCHAR(100) -- Description: Current status of the flow computer, active ('1') or inactive ('2'),
# 	Unidad_Destino VARCHAR(100) -- Description: Target unit within the target group for data or commands,
# 	Unidad_Fuente  VARCHAR(100) -- Description: Source unit within the source group from which data or commands are issued,
# 	Tipo_Protocolo  VARCHAR(100) -- Description: Type of protocol used for communication,
# 	IdFirmware_fk INT -- Description: Foreign key linking flow computers with respective firmware,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.fcs_computador_medidor(
# 	Codigo_Medidor  VARCHAR(100) -- Description: Unique identifier meter code (1,2,3,4,5...10),
# 	Estado VARCHAR(100) -- Description: Current status of the computer-meter association active ('2') or inactive ('1') or not available ('0'),
# 	Id_Sisema_Medicion INT -- Description: Foreign key linking meters with measurement systems,
# 	IdComputador_fk INT -- Description: Foreign key linking meters with flow computers,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.var_tipo_variable(
# 	Id INT -- Description: Unique identifier for each variable,
# 	Nombre VARCHAR(100) -- Description: Measured variable name,
# 	Estado VARCHAR(100) -- Description: Current status of the variable, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.var_variable_datos(
# 	Fecha DATETIME -- Description: Date and time when the variable data was measured,
# 	Valor FLOAT -- Description: Numeric value of the variable measured,
# 	Valor_String VARCHAR(100) -- Description: String representation of the variable value, for non-numeric data,
# 	idSistemaMedicion_fk INT -- Description: Foreign key linking variable measured value with respective variable name,
# 	IdVariable_fk INT -- Description: Foreign key linking variable name with respective measured value,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.equ_equipo(
# 	Id INT -- Description: Unique identifier for each equipment,
# 	Serial VARCHAR(550) -- Description: Serial number of the equipment,
# 	Estado VARCHAR(10) -- Description: Current status of the equipment, active ('ACT') or inactive ('INA'),
# 	Modelo VARCHAR(200) -- Description: Model of the equipment,
# 	Caracteristica VARCHAR(200) -- Description: Characteristics or specifications of the equipment,
# 	Categoria VARCHAR(3) -- Description: Category code of the equipment,
# 	IdTipoEquipo_fk INT -- Description: Foreign key linking equipment type with equipment,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.teq_tipo_equipo(
# 	Id INT -- Description: Unique identifier for each equipment type,
# 	Nombre VARCHAR(150) -- Description: Name or description of the equipment type,
# 	Estado VARCHAR(10) -- Description: Current status of the equipment type, active ('ACT') or inactive ('INA'),
# 	EsMultivariable BIT -- Description: Indicates whether this equipment type is capable of measuring multiple variables,
# 	IdClasificacion_fk INT -- Description: Foreign key linking equipment type with respective equipment classification,
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.teq_clasificacion(
# 	Id INT -- Description: Unique identifier for each equipment classification,
# 	Nombre VARCHAR(150) -- Description: Name of the classification (e.g: 'Medidor primario', ' Medidor secundario', ' Medidor terciario', ' Válvulas e accesorios'),
# 	Estado VARCHAR(10) -- Description: Current status of the classification, active ('ACT') or inactive ('INA'),
# );
# CREATE TABLE IF NOT EXISTS dbo_v2.med_tag(
# 	Nombre VARCHAR(MAX) -- Description: Combined name from measurement system and equipment,
# 	Estado VARCHAR(10) -- Description: Current status of the tag, active ('ACT') or inactive ('INA'),
# 	SensoresHabilitadosMv VARCHAR(100) -- Description: Information about enabled sensors for multivariable equipment,
# 	IdSistemaMedicion_fk INT -- Description: Foreign key linking measurement systems with their respective measurement system tag,
# 	IdEquipo_fk INT -- Description: Foreign key linking equipment with respective measurement system tag,
# );
#
# dbo_v2.flu_tipo_fluido.Id can be joined with dbo_v2.med_sistema_medicion.IdTipoFluido_fk
# dbo_v2.med_sistema_medicion.IdPlataforma_fk can be joined with dbo_v2.pla_plataforma.Id
# dbo_v2.fcs_computador_medidor.Id_Sisema_Medicion can be joined with dbo_v2.med_sistema_medicion.Id
# dbo_v2.fcs_computador_medidor.IdComputador_fk can be joined with dbo_v2.fcs_computadores.Id
# dbo_v2.fcs_computadores.IdFirmware_fk can be joined with dbo_v2.fcs_firmware.Id
# dbo_v2.med_sistema_medicion.Id can be joined with dbo_v2.med_tag.IdSistemaMedicion_fk
# dbo_v2.equ_equipo.Id can be joined with dbo_v2.med_tag.IdEquipo_fk
# dbo_v2.equ_equipo.IdTipoEquipo_fk can be joined with dbo_v2.teq_tipo_equipo.Id
# dbo_v2.teq_clasificacion.Id can be joined with dbo_v2.teq_tipo_equipo.IdClasificacion_fk
# dbo_v2.var_variable_datos.idSistemaMedicion_fk can be joined with dbo_v2.med_sistema_medicion.Id
# dbo_v2.var_tipo_variable.Id can be joined with dbo_v2.var_variable_datos.IdVariable_fk
# dbo_v2.fcs_firmware.IdTipo_Computador can be joined with dbo_v2.fcs_tipo_computador.Id
# dbo_v2.med_tipo_medicion.Id can be joined with dbo_v2.med_sistema_medicion.IdAplicabilidad_fk
