# %%
import sys
sys.path.append("C:\\Users\\lauth\\OneDrive\\Desktop\\sql_assistant_v3")

# %%
from src.document_indexing.data_functions.data_functions import (
    read_tables_descriptions,
    read_tables_data,
    read_sql_examples,
    read_classify_dictionary,
    read_database_semantics
)

# %%
read_database_semantics("semantics_relations").head(5)
# Out:
#                         semantic_table_relation            meta_table_1  \
# 0            Every measurement system use fluid         flu_tipo_fluido
# 1          Measurement system is from platform     med_sistema_medicion
# 2     Meter is assigned to a measurement system  fcs_computador_medidor
# 3                 Flow computer includes meters  fcs_computador_medidor
# 4  Every flow computer has firmware or versions        fcs_computadores
#
#            meta_table_2             meta_k1  \
# 0  med_sistema_medicion                  Id
# 1        pla_plataforma     IdPlataforma_fk
# 2  med_sistema_medicion  Id_Sisema_Medicion
# 3      fcs_computadores     IdComputador_fk
# 4          fcs_firmware       IdFirmware_fk
#
#                                  meta_k1_description          meta_k2  \
# 0               Unique identifier for the fluid type  IdTipoFluido_fk
# 1  Foreign key linking measurement systems with p...               Id
# ...
